# %% [markdown]
# # **Operatorlar**

# %% [markdown]
# # **Arifmetik operatorlar**

# %%
a = 8
b = 10

# %% [markdown]
# ```+``` - qo'shish operatori

# %%
a + b
# Out:
# 18

# %% [markdown]
# ```-``` - ayirish operatori

# %%
b - a
# Out:
# 2

# %% [markdown]
# ```*``` - ko'paytirish operatori

# %%
a * b
# Out:
# 80

# %% [markdown]
# ```/``` - bo'lish operatori

# %%
b / a
# Out:
# 1.25

# %% [markdown]
# ```%``` - bo'lgandagi qoldiqni hisoblash operatori

# %%
b % a
# Out:
# 2

# %% [markdown]
# ```//``` - bo'lgandagi butun qismni (bo'linmani) hisoblash operatori

# %%
b // a
# Out:
# 1

# %% [markdown]
# ```**``` - darajaga ko'tarish operatori

# %%
a ** 3
# Out:
# 512

# %% [markdown]
# # **Assignment Operators**

# %% [markdown]
# ```=``` operatori

# %%
x = 5

# %% [markdown]
# ```+=``` va  ```-=``` operatorlari

# %%
x += 3 # x = x + 3

# %%
x -= 3  # x = x - 3

# %%
x //= 3 # x = x // 3

# %% [markdown]
# ```:=``` operatori

# %%
print(c:=3)
# Out:
# 3

# %% [markdown]
# # **Taqqoslash Operatorlari**

# %% [markdown]
# ```==```
#  tengmi?

# %%
b == 4
# Out:
# False

# %% [markdown]
# ```!=```  teng emasmi?

# %%
a != 20
# Out:
# True

# %% [markdown]
# ```>```  ... dan kattami?

# %%
a > b
# Out:
# False

# %% [markdown]
# ```<``` ...dan kichikmi?

# %%
a < b
# Out:
# True

# %% [markdown]
# ```>=``` ... dan katta yoki tengmi?

# %%
a >= b
# Out:
# False

# %% [markdown]
# ```<=``` ...dan kichik yoki tengmi?

# %%
a <= b
# Out:
# True

# %% [markdown]
# # **Mantiqiy Operatorlar**

# %% [markdown]
# ```and``` - mantiqiy va operatori (konyuksiya)

# %%
a > 20 and b < 10
# Out:
# False

# %% [markdown]
# ```or``` - mantiqiy yoki operatori (dizyunksiya)

# %%
a == 8 or b > 30
# Out:
# True

# %% [markdown]
# ```not``` - mantiqiy inkor operatori (inversiya)

# %%
not (b > 100)
# Out:
# True

# %% [markdown]
# # **Identifikatsiya operatorlari**

# %% [markdown]
# ```is``` - ikkita obyekt aynan bir xilmi?

# %%
a = 8
b = 8.0

b is a

# %% [markdown]
# ```is not``` - ikkita obyekt aynan bir xil emasmi?

# %%
a is not b
# Out:
# True

# %% [markdown]
# # **Bitwise operatorlari**

# %%
a = 1001
b = 1100

# %%
#Bitwise and - &
a & b #1000
# Out:
# 72

# %%
#Bitwise or - |
a | b #11010000
# Out:
# 2029
