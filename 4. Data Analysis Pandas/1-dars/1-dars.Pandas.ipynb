# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # **Pandas Series**

# %%
s = pd.Series([4, 5, 6, 7, 10, 21],
              index = [10, 20, 30, 40, 50, 60],
              dtype = np.uint32)

s
# Out:
# 10     4
# 20     5
# 30     6
# 40     7
# 50    10
# 60    21
# dtype: uint32

# %%
s.shape
# Out:
# (6,)

# %%
s.dtype
# Out:
# dtype('uint32')

# %%
s[50]
# Out:
# 10

# %%
s.index
# Out:
# Index([10, 20, 30, 40, 50, 60], dtype='int64')

# %%
s.index.name = "Biz bergan indekslar"

# %%
s.index
# Out:
# Index([10, 20, 30, 40, 50, 60], dtype='int64', name='Biz bergan indekslar')

# %%
s.index = ['a', 'b', 'c', 'd', 'e', 'f']

# %%
s.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e', 'f'], dtype='object')

# %%
dictionary = {'a': 10, 'b': 20, 'c': 30, 'd': 40, 'e': 50}

pd.Series(dictionary)
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64

# %%
dictionary = {'a': 10, 'b': 20, 'c': 30, 'd': 40, 'e': 50}

s = pd.Series(dictionary)

dictionary = {'f': 10, 'g': 20, 'h': 30, 'i': 40, 'e': 70}

s2 = pd.Series(dictionary)

# %%
s
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64

# %%
s2
# Out:
# f    10
# g    20
# h    30
# i    40
# e    70
# dtype: int64

# %%
s + s2
# Out:
# a      NaN
# b      NaN
# c      NaN
# d      NaN
# e    120.0
# f      NaN
# g      NaN
# h      NaN
# i      NaN
# dtype: float64

# %%
s - 3
# Out:
# a     7
# b    17
# c    27
# d    37
# e    47
# dtype: int64

# %%
np.exp(s)
# Out:
# a    2.202647e+04
# b    4.851652e+08
# c    1.068647e+13
# d    2.353853e+17
# e    5.184706e+21
# dtype: float64

# %% [markdown]
# # **Pandas DataFrame**

# %%
dictionary = {
    'Age': [30, 40, 12, 22, 90, 85],
    'Sex': ['M', 'F', 'M', "M", "F", "F"],
    'Name': ['John', 'Jonibek', 'Abdulla', 'Temur', 'Farid', 'Aktam']
}

df = pd.DataFrame(dictionary,
                  index=['a', 'b', 'c', 'd', 'e', 'f'],
                  columns=['Age', 'Sex', 'Name'])

# %%
df
# Out:
#    Age Sex     Name
# a   30   M     John
# b   40   F  Jonibek
# c   12   M  Abdulla
# d   22   M    Temur
# e   90   F    Farid
# f   85   F    Aktam

# %%
df.shape
# Out:
# (6, 3)

# %%
df.head()
# Out:
#    Yosh Jinsi     Name
# 0    30  Male     John
# 1    40     F  Jonibek
# 2    12     M  Abdulla
# 3    22     M    Temur
# 4    90     F    Farid

# %%
df.tail(3)
# Out:
#    Yosh Jinsi   Name
# 3    22     M  Temur
# 4    90     F  Farid
# 5    85     F  Aktam

# %%
df.sample(3)
# Out:
#    Yosh Jinsi     Name
# 5    85     F    Aktam
# 1    40     F  Jonibek
# 0    30  Male     John

# %%
df.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e', 'f'], dtype='object')

# %%
df.columns
# Out:
# Index(['Yosh', 'Jinsi', 'Name'], dtype='object')

# %%
df.index.name = 'Letters'

# %%
df
# Out:
#          Age   Sex     Name
# Letters
# a         30  Male     John
# b         40     F  Jonibek
# c         12     M  Abdulla
# d         22     M    Temur
# e         90     F    Farid
# f         85     F    Aktam

# %%
df['Name']
# Out:
# Letters
# a       John
# b    Jonibek
# c    Abdulla
# d      Temur
# e      Farid
# f      Aktam
# Name: Name, dtype: object

# %%
df[['Name', 'Age']]
# Out:
#             Name  Age
# Letters
# a           John   30
# b        Jonibek   40
# c        Abdulla   12
# d          Temur   22
# e          Farid   90
# f          Aktam   85

# %%
df.Name
# Out:
# Letters
# a       John
# b    Jonibek
# c    Abdulla
# d      Temur
# e      Farid
# f      Aktam
# Name: Name, dtype: object
