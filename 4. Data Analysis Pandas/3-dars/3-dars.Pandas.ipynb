# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://raw.githubusercontent.com/iRavshan/ML-Projects/master/datasets/police.csv')

# %%
df
# Out:
#         stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 0      2005-01-02     01:55          NaN             M          1985.0
# 1      2005-01-18     08:15          NaN             M          1965.0
# 2      2005-01-23     23:15          NaN             M          1972.0
# 3      2005-02-20     17:15          NaN             M          1986.0
# 4      2005-03-14     10:00          NaN             F          1984.0
# ...           ...       ...          ...           ...             ...
# 91736  2015-12-31     20:27          NaN             M          1986.0
# 91737  2015-12-31     20:35          NaN             F          1982.0
# 91738  2015-12-31     20:45          NaN             M          1992.0
# 91739  2015-12-31     21:42          NaN             M          1993.0
# 91740  2015-12-31     22:46          NaN             M          1959.0
#
#        driver_age driver_race                   violation_raw  \
# ...

# %%
df.shape
# Out:
# (91741, 15)

# %%
df.head(10)
# Out:
#     stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 0  2005-01-02     01:55          NaN             M          1985.0
# 1  2005-01-18     08:15          NaN             M          1965.0
# 2  2005-01-23     23:15          NaN             M          1972.0
# 3  2005-02-20     17:15          NaN             M          1986.0
# 4  2005-03-14     10:00          NaN             F          1984.0
# 5  2005-03-23     09:45          NaN             M          1982.0
# 6  2005-04-01     17:30          NaN             M          1969.0
# 7  2005-06-06     13:20          NaN             F          1986.0
# 8  2005-07-13     10:15          NaN             M          1970.0
# 9  2005-07-13     15:45          NaN             M          1970.0
#
#    driver_age driver_race                   violation_raw  violation  \
# 0        20.0       White                        Speeding   Speeding
# 1        40.0       White                        Speeding   Speeding
# ...

# %%
df.tail(7)
# Out:
#         stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 91734  2015-12-31     20:20          NaN             M          1993.0
# 91735  2015-12-31     20:25          NaN             M          1992.0
# 91736  2015-12-31     20:27          NaN             M          1986.0
# 91737  2015-12-31     20:35          NaN             F          1982.0
# 91738  2015-12-31     20:45          NaN             M          1992.0
# 91739  2015-12-31     21:42          NaN             M          1993.0
# 91740  2015-12-31     22:46          NaN             M          1959.0
#
#        driver_age driver_race                   violation_raw  \
# 91734        22.0       White                        Speeding
# 91735        23.0    Hispanic                        Speeding
# 91736        29.0       White                        Speeding
# 91737        33.0       White  Equipment/Inspection Violation
# 91738        23.0       White         Other Traffic Violation
# ...

# %%
df.sample(12)
# Out:
#         stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 69079  2013-05-21     08:44          NaN             M          1974.0
# 72623  2013-10-29     07:16          NaN             M          1992.0
# 48432  2011-03-24     18:24          NaN             M          1977.0
# 67786  2013-03-21     09:31          NaN             M          1971.0
# 73126  2013-11-23     23:50          NaN             M          1986.0
# 9339   2006-08-21     03:10          NaN             F          1983.0
# 83185  2015-01-03     12:54          NaN             M          1989.0
# 66655  2013-01-25     09:57          NaN             M          1979.0
# 57799  2012-03-14     14:10          NaN             M          1964.0
# 59091  2012-04-19     01:29          NaN             M          1973.0
# 62677  2012-08-11     07:53          NaN             F          1991.0
# 64868  2012-11-07     06:40          NaN             F          1989.0
#
# ...

# %%
df.loc[9339:9440] #location
# Out:
#        stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 9339  2006-08-21     03:10          NaN             F          1983.0
# 9340  2006-08-21     08:43          NaN             M          1975.0
# 9341  2006-08-21     11:30          NaN             F          1956.0
# 9342  2006-08-21     11:39          NaN             M          1976.0
# 9343  2006-08-21     14:05          NaN             F          1986.0
# ...          ...       ...          ...           ...             ...
# 9436  2006-08-24     23:40          NaN             M          1932.0
# 9437  2006-08-25     00:05          NaN             F          1986.0
# 9438  2006-08-25     00:25          NaN             M          1983.0
# 9439  2006-08-25     00:30          NaN             M          1981.0
# 9440  2006-08-25     01:10          NaN             M          1984.0
#
#       driver_age driver_race                   violation_raw  \
# 9339        23.0       White                        Speeding
# ...

# %%
df.iloc[9339] #index location
# Out:
# stop_date             2006-08-21
# stop_time                  03:10
# county_name                  NaN
# driver_gender                  F
# driver_age_raw            1983.0
# driver_age                  23.0
# driver_race                White
# violation_raw           Speeding
# violation               Speeding
# search_conducted           False
# search_type                  NaN
# stop_outcome            Citation
# is_arrested                False
# stop_duration          16-30 Min
# drugs_related_stop         False
# Name: 9339, dtype: object

# %% [markdown]
# # **Manipulating a DataFrame**

# %% [markdown]
# # **Transpose using `.T`**

# %%
df2 = df.T

# %%
df2.sample(10)
# Out:
#                          0           1           2              3      \
# violation             Speeding    Speeding    Speeding          Other
# search_conducted         False       False       False          False
# driver_race              White       White       White          White
# stop_time                01:55       08:15       23:15          17:15
# county_name                NaN         NaN         NaN            NaN
# stop_date           2005-01-02  2005-01-18  2005-01-23     2005-02-20
# stop_outcome          Citation    Citation    Citation  Arrest Driver
# drugs_related_stop       False       False       False          False
# search_type                NaN         NaN         NaN            NaN
# driver_age_raw          1985.0      1965.0      1972.0         1986.0
#
#                          4           5           6           7      \
# violation             Speeding   Equipment    Speeding    Speeding
# ...

# %%
df.sample(10)
# Out:
#         stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 1812   2005-12-01     23:15          NaN             M          1962.0
# 55699  2012-01-17     12:01          NaN             M          1991.0
# 36643  2009-08-08     02:50          NaN             F          1987.0
# 39167  2009-12-21     17:34          NaN             M          1969.0
# 91486  2015-12-17     19:55          NaN             M          1967.0
# 51321  2011-07-29     14:28          NaN             M          1990.0
# 42166  2010-05-06     07:25          NaN             M          1969.0
# 37616  2009-09-30     13:33          NaN             M          1970.0
# 44600  2010-08-27     09:47          NaN             F          1977.0
# 57128  2012-02-25     23:18          NaN           NaN             NaN
#
#        driver_age driver_race                   violation_raw  \
# 1812         43.0       White                        Speeding
# ...

# %% [markdown]
# # **The `sort_index()` method**

# %%
test_df = df.sample(10)

test_df
# Out:
#         stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 66320  2013-01-13     11:46          NaN             F          1976.0
# 72396  2013-10-17     16:31          NaN             F          1964.0
# 44503  2010-08-22     02:34          NaN             M          1983.0
# 79994  2014-08-19     09:53          NaN             M          1977.0
# 24895  2008-04-05     09:40          NaN             M          1950.0
# 2250   2005-12-18     07:15          NaN             F          1967.0
# 36418  2009-07-27     10:08          NaN             M          1955.0
# 11059  2006-10-19     00:40          NaN             M          1964.0
# 30294  2008-11-10     06:15          NaN             F          1983.0
# 17147  2007-05-21     15:40          NaN             M          1957.0
#
#        driver_age driver_race                   violation_raw  violation  \
# 66320        37.0       White                        Speeding   Speeding
# ...

# %%
test_df.sort_index()
# Out:
#         stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 2250   2005-12-18     07:15          NaN             F          1967.0
# 11059  2006-10-19     00:40          NaN             M          1964.0
# 17147  2007-05-21     15:40          NaN             M          1957.0
# 24895  2008-04-05     09:40          NaN             M          1950.0
# 30294  2008-11-10     06:15          NaN             F          1983.0
# 36418  2009-07-27     10:08          NaN             M          1955.0
# 44503  2010-08-22     02:34          NaN             M          1983.0
# 66320  2013-01-13     11:46          NaN             F          1976.0
# 72396  2013-10-17     16:31          NaN             F          1964.0
# 79994  2014-08-19     09:53          NaN             M          1977.0
#
#        driver_age driver_race                   violation_raw  violation  \
# 2250         38.0       White                        Speeding   Speeding
# ...

# %% [markdown]
# # **The `sort_values()` method**

# %%
df.sort_values(by=['stop_date', 'stop_time']).head()
# Out:
#     stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 0  2005-01-02     01:55          NaN             M          1985.0
# 1  2005-01-18     08:15          NaN             M          1965.0
# 2  2005-01-23     23:15          NaN             M          1972.0
# 3  2005-02-20     17:15          NaN             M          1986.0
# 4  2005-03-14     10:00          NaN             F          1984.0
#
#    driver_age driver_race     violation_raw violation  search_conducted  \
# 0        20.0       White          Speeding  Speeding             False
# 1        40.0       White          Speeding  Speeding             False
# 2        33.0       White          Speeding  Speeding             False
# 3        19.0       White  Call for Service     Other             False
# 4        21.0       White          Speeding  Speeding             False
#
#   search_type   stop_outcome is_arrested stop_duration  drugs_related_stop
# ...

# %% [markdown]
# # **The `reindex()` function**

# %%
test_df = df.sample(5)

test_df
# Out:
#         stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 27768  2008-07-30     02:24          NaN             M          1970.0
# 26495  2008-06-08     15:54          NaN             M          1946.0
# 81851  2014-10-29     18:46          NaN             F          1969.0
# 62441  2012-08-03     20:44          NaN             F          1981.0
# 37741  2009-10-08     00:00          NaN             M          1972.0
#
#        driver_age driver_race                   violation_raw  \
# 27768        38.0    Hispanic  Equipment/Inspection Violation
# 26495        62.0       White         Other Traffic Violation
# 81851        45.0       White          Registration Violation
# 62441        31.0       Black         Other Traffic Violation
# 37741        37.0       Black  Equipment/Inspection Violation
#
#                  violation  search_conducted search_type stop_outcome  \
# 27768            Equipment             False         NaN     Citation
# ...

# %%
test_df.reindex(['a', 'b', 'c', 'd', 'e', 'f'])
# Out:
#   stop_date stop_time  county_name driver_gender  driver_age_raw  driver_age  \
# a       NaN       NaN          NaN           NaN             NaN         NaN
# b       NaN       NaN          NaN           NaN             NaN         NaN
# c       NaN       NaN          NaN           NaN             NaN         NaN
# d       NaN       NaN          NaN           NaN             NaN         NaN
# e       NaN       NaN          NaN           NaN             NaN         NaN
# f       NaN       NaN          NaN           NaN             NaN         NaN
#
#   driver_race violation_raw violation search_conducted search_type  \
# a         NaN           NaN       NaN              NaN         NaN
# b         NaN           NaN       NaN              NaN         NaN
# c         NaN           NaN       NaN              NaN         NaN
# d         NaN           NaN       NaN              NaN         NaN
# e         NaN           NaN       NaN              NaN         NaN
# ...

# %% [markdown]
# # **Adding a new column**

# %%
from datetime import datetime
df['current_date_time'] = datetime.now()

# %%
df.
# Out:
#     stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 0  2005-01-02     01:55          NaN             M          1985.0
# 1  2005-01-18     08:15          NaN             M          1965.0
# 2  2005-01-23     23:15          NaN             M          1972.0
# 3  2005-02-20     17:15          NaN             M          1986.0
# 4  2005-03-14     10:00          NaN             F          1984.0
#
#    driver_age driver_race     violation_raw violation  search_conducted  \
# 0        20.0       White          Speeding  Speeding             False
# 1        40.0       White          Speeding  Speeding             False
# 2        33.0       White          Speeding  Speeding             False
# 3        19.0       White  Call for Service     Other             False
# 4        21.0       White          Speeding  Speeding             False
#
#   search_type   stop_outcome is_arrested stop_duration  drugs_related_stop  \
# ...

# %% [markdown]
# # **Delete an existing column**

# %% [markdown]
# # **The `at[]` (By label)**

# %% [markdown]
# # **The `iat[]` (By position)**

# %% [markdown]
# # **Conditional updating of values**

# %% [markdown]
# # **The `dropna()` method**

# %% [markdown]
# # **The `fillna()` method**

# %% [markdown]
# # **Statistical Exploratory data analysis**

# %% [markdown]
# # **The `info()` function**

# %% [markdown]
# # **The `describe()` function**

# %% [markdown]
# # **The `value_counts()` function**

# %% [markdown]
# # **The `mean()` function**

# %% [markdown]
# # **The `std()` function**
