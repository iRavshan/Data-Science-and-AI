# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://raw.githubusercontent.com/iRavshan/pro_data_scientist/main/datasets/police.csv')

# %%
df.head()
# Out:
#    stop_date stop_time  county_name driver_gender  driver_age_raw  driver_age  \
# 0   1/2/2005      1:55          NaN             M          1985.0        20.0
# 1  1/18/2005      8:15          NaN             M          1965.0        40.0
# 2  1/23/2005     23:15          NaN             M          1972.0        33.0
# 3  2/20/2005     17:15          NaN             M          1986.0        19.0
# 4  3/14/2005     10:00          NaN             F          1984.0        21.0
#
#   driver_race     violation_raw violation  search_conducted search_type  \
# 0       White          Speeding  Speeding             False         NaN
# 1       White          Speeding  Speeding             False         NaN
# 2       White          Speeding  Speeding             False         NaN
# 3       White  Call for Service     Other             False         NaN
# 4       White          Speeding  Speeding             False         NaN
#
#     stop_outcome is_arrested stop_duration  drugs_related_stop
# ...

# %%
del df['county_name']

# %%
df.dropna(inplace=True)

# %%
df.head()
# Out:
#      stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 24   8/28/2005      1:00             M          1979.0        26.0
# 40   10/1/2005      0:00             M          1988.0        17.0
# 41   10/1/2005      0:00             M          1988.0        17.0
# 80   10/2/2005      9:30             M          1975.0        30.0
# 106  10/3/2005     14:00             M          1978.0        27.0
#
#     driver_race                   violation_raw         violation  \
# 24        White         Other Traffic Violation  Moving violation
# 40        White  Equipment/Inspection Violation         Equipment
# 41        White  Equipment/Inspection Violation         Equipment
# 80        White                        Speeding          Speeding
# 106       Black  Equipment/Inspection Violation         Equipment
#
#      search_conducted                          search_type   stop_outcome  \
# 24               True  Incident to Arrest,Protective Frisk  Arrest Driver
# ...

# %% [markdown]
# # **Dublikat ma'lumotlarni aniqlash**

# %%
df.duplicated()
# Out:
# 24       False
# 40       False
# 41       False
# 80       False
# 106      False
#          ...
# 91494    False
# 91548    False
# 91672    False
# 91700    False
# 91708    False
# Length: 3193, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 9

# %%
df[df.duplicated()]
# Out:
#         stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 340    10/12/2005     20:30             M          1987.0        18.0
# 900     11/2/2005      1:45             F          1987.0        18.0
# 1670   11/27/2005      8:40             M          1984.0        21.0
# 2293   12/19/2005     19:21             M          1957.0        48.0
# 2706     1/6/2006     16:40             M          1981.0        25.0
# 2928    1/12/2006     11:35             M          1986.0        20.0
# 4148    2/21/2006      1:40             M          1985.0        21.0
# 18646   7/15/2007     18:08             M          1988.0        19.0
# 33017    3/6/2009      1:40             M          1990.0        19.0
#
#       driver_race                   violation_raw            violation  \
# 340      Hispanic         Other Traffic Violation     Moving violation
# 900         Black          Registration Violation  Registration/plates
# ...

# %% [markdown]
# Takroriy qiymatlarni mos ustunlar bo'yicha izlash

# %%
df.duplicated(subset=['stop_date', 'stop_time']).sum()
# Out:
# 34

# %%
df[df.duplicated(subset=['stop_date', 'stop_time'])].shape
# Out:
# (34, 14)

# %% [markdown]
# # **Takrorlangan ma'lumotlarni o'chirish**

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (3184, 14)

# %%
df.drop_duplicates(subset=['stop_date', 'stop_time'])
# Out:
#         stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 24      8/28/2005      1:00             M          1979.0        26.0
# 40      10/1/2005      0:00             M          1988.0        17.0
# 80      10/2/2005      9:30             M          1975.0        30.0
# 106     10/3/2005     14:00             M          1978.0        27.0
# 118     10/4/2005      1:20             M          1956.0        49.0
# ...           ...       ...           ...             ...         ...
# 91494  12/18/2015      9:30             M          1966.0        49.0
# 91548  12/21/2015      1:39             M          1986.0        29.0
# 91672  12/28/2015     11:05             F          1996.0        19.0
# 91700  12/30/2015      8:51             F          1987.0        28.0
# 91708  12/30/2015     13:15             M          1992.0        23.0
#
#       driver_race                   violation_raw            violation  \
# ...
