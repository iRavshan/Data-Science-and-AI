# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://raw.githubusercontent.com/iRavshan/pro_data_scientist/main/datasets/police.csv')

# %%
df.head()
# Out:
#    stop_date stop_time  county_name driver_gender  driver_age_raw  driver_age  \
# 0   1/2/2005      1:55          NaN             M          1985.0        20.0
# 1  1/18/2005      8:15          NaN             M          1965.0        40.0
# 2  1/23/2005     23:15          NaN             M          1972.0        33.0
# 3  2/20/2005     17:15          NaN             M          1986.0        19.0
# 4  3/14/2005     10:00          NaN             F          1984.0        21.0
#
#   driver_race     violation_raw violation  search_conducted search_type  \
# 0       White          Speeding  Speeding             False         NaN
# 1       White          Speeding  Speeding             False         NaN
# 2       White          Speeding  Speeding             False         NaN
# 3       White  Call for Service     Other             False         NaN
# 4       White          Speeding  Speeding             False         NaN
#
#     stop_outcome is_arrested stop_duration  drugs_related_stop
# ...

# %% [markdown]
# # **Ustunlarni qayta nomlash**

# %%
df.rename(columns=str.upper)
# Out:
#         STOP_DATE STOP_TIME  COUNTY_NAME DRIVER_GENDER  DRIVER_AGE_RAW  \
# 0        1/2/2005      1:55          NaN             M          1985.0
# 1       1/18/2005      8:15          NaN             M          1965.0
# 2       1/23/2005     23:15          NaN             M          1972.0
# 3       2/20/2005     17:15          NaN             M          1986.0
# 4       3/14/2005     10:00          NaN             F          1984.0
# ...           ...       ...          ...           ...             ...
# 91736  12/31/2015     20:27          NaN             M          1986.0
# 91737  12/31/2015     20:35          NaN             F          1982.0
# 91738  12/31/2015     20:45          NaN             M          1992.0
# 91739  12/31/2015     21:42          NaN             M          1993.0
# 91740  12/31/2015     22:46          NaN             M          1959.0
#
#        DRIVER_AGE DRIVER_RACE                   VIOLATION_RAW  \
# ...

# %%
df.head()
# Out:
#    stop_date stop_time  county_name driver_gender  driver_age_raw  driver_age  \
# 0   1/2/2005      1:55          NaN             M          1985.0        20.0
# 1  1/18/2005      8:15          NaN             M          1965.0        40.0
# 2  1/23/2005     23:15          NaN             M          1972.0        33.0
# 3  2/20/2005     17:15          NaN             M          1986.0        19.0
# 4  3/14/2005     10:00          NaN             F          1984.0        21.0
#
#   driver_race     violation_raw violation  search_conducted search_type  \
# 0       White          Speeding  Speeding             False         NaN
# 1       White          Speeding  Speeding             False         NaN
# 2       White          Speeding  Speeding             False         NaN
# 3       White  Call for Service     Other             False         NaN
# 4       White          Speeding  Speeding             False         NaN
#
#     stop_outcome is_arrested stop_duration  drugs_related_stop
# ...

# %%
df.rename(columns={'county_name': 'county', 'drugs_related_stop': 'drugs_related'}, inplace=True)

# %%
df.columns
# Out:
# Index(['stop_date', 'stop_time', 'county', 'driver_gender', 'driver_age_raw',
#        'driver_age', 'driver_race', 'violation_raw', 'violation',
#        'search_conducted', 'search_type', 'stop_outcome', 'is_arrested',
#        'stop_duration', 'drugs_related'],
#       dtype='object')

# %% [markdown]
# # **Qiymatlarga ishlov berish**

# %% [markdown]
# `replace` funksiyasi

# %%
df.replace(['M', 'F'], ['Erkak', 'Ayol'], inplace=True)

# %%
df.head()
# Out:
#    stop_date stop_time  county driver_gender  driver_age_raw  driver_age  \
# 0   1/2/2005      1:55     NaN         Erkak          1985.0        20.0
# 1  1/18/2005      8:15     NaN         Erkak          1965.0        40.0
# 2  1/23/2005     23:15     NaN         Erkak          1972.0        33.0
# 3  2/20/2005     17:15     NaN         Erkak          1986.0        19.0
# 4  3/14/2005     10:00     NaN          Ayol          1984.0        21.0
#
#   driver_race     violation_raw violation  search_conducted search_type  \
# 0       White          Speeding  Speeding             False         NaN
# 1       White          Speeding  Speeding             False         NaN
# 2       White          Speeding  Speeding             False         NaN
# 3       White  Call for Service     Other             False         NaN
# 4       White          Speeding  Speeding             False         NaN
#
#     stop_outcome is_arrested stop_duration  drugs_related
# ...

# %%
df['driver_gender'].unique()
# Out:
# array(['Erkak', 'Ayol', nan], dtype=object)

# %% [markdown]
# `map` funksiyasi

# %%
del df['county']

# %%
df.dropna(inplace=True)

# %%
df['driver_age_raw'] = df['driver_age_raw'].map(lambda x: round(x))

# %%
df['driver_age_raw']
# Out:
# 24       1979
# 40       1988
# 41       1988
# 80       1975
# 106      1978
#          ...
# 91494    1966
# 91548    1986
# 91672    1996
# 91700    1987
# 91708    1992
# Name: driver_age_raw, Length: 3193, dtype: int64

# %%
df['driver_age'] = df['driver_age'].map(lambda x: int(x))

# %%
df.head()
# Out:
#      stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 24   8/28/2005      1:00         Erkak            1979          26
# 40   10/1/2005      0:00         Erkak            1988          17
# 41   10/1/2005      0:00         Erkak            1988          17
# 80   10/2/2005      9:30         Erkak            1975          30
# 106  10/3/2005     14:00         Erkak            1978          27
#
#     driver_race                   violation_raw         violation  \
# 24        White         Other Traffic Violation  Moving violation
# 40        White  Equipment/Inspection Violation         Equipment
# 41        White  Equipment/Inspection Violation         Equipment
# 80        White                        Speeding          Speeding
# 106       Black  Equipment/Inspection Violation         Equipment
#
#      search_conducted                          search_type   stop_outcome  \
# 24               True  Incident to Arrest,Protective Frisk  Arrest Driver
# ...

# %%
df['driver_age'].dtype
# Out:
# dtype('int64')

# %%
df['driver_age'] = df['driver_age'].astype(np.float64)

# %%
df.head()
# Out:
#      stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 24   8/28/2005      1:00         Erkak            1979        26.0
# 40   10/1/2005      0:00         Erkak            1988        17.0
# 41   10/1/2005      0:00         Erkak            1988        17.0
# 80   10/2/2005      9:30         Erkak            1975        30.0
# 106  10/3/2005     14:00         Erkak            1978        27.0
#
#     driver_race                   violation_raw         violation  \
# 24        White         Other Traffic Violation  Moving violation
# 40        White  Equipment/Inspection Violation         Equipment
# 41        White  Equipment/Inspection Violation         Equipment
# 80        White                        Speeding          Speeding
# 106       Black  Equipment/Inspection Violation         Equipment
#
#      search_conducted                          search_type   stop_outcome  \
# 24               True  Incident to Arrest,Protective Frisk  Arrest Driver
# ...

# %%
df.replace([True, False], [1, 0], inplace=True)

# %%
df.head()
# Out:
#      stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 24   8/28/2005      1:00         Erkak            1979        26.0
# 40   10/1/2005      0:00         Erkak            1988        17.0
# 41   10/1/2005      0:00         Erkak            1988        17.0
# 80   10/2/2005      9:30         Erkak            1975        30.0
# 106  10/3/2005     14:00         Erkak            1978        27.0
#
#     driver_race                   violation_raw         violation  \
# 24        White         Other Traffic Violation  Moving violation
# 40        White  Equipment/Inspection Violation         Equipment
# 41        White  Equipment/Inspection Violation         Equipment
# 80        White                        Speeding          Speeding
# 106       Black  Equipment/Inspection Violation         Equipment
#
#      search_conducted                          search_type   stop_outcome  \
# 24                  1  Incident to Arrest,Protective Frisk  Arrest Driver
# ...

# %%
df['is_arrested'].value_counts()
# Out:
# is_arrested
# 0    2100
# 1    1093
# Name: count, dtype: int64

# %% [markdown]
# `applymap()` va `apply()` funksiyalari
