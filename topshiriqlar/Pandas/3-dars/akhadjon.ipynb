# %% [markdown]
# **1.** Quyidagi havolada berilgan datasetni DataFrame obyektiga o'qib oling:
#
# https://github.com/iRavshan/pro_data_scientist/blob/main/datasets/police.csv

# %%
df = pd.read_csv("E:\Data science\pro_data_scientist\datasets\police.csv")

# %% [markdown]
# **2.** Datasetning o'lchamini, ya'ni nechta qator va ustunlardan iborat ekanligini aniqlang

# %%
df.shape
# Out:
# (91741, 15)

# %% [markdown]
# **3.** DataFrame`ning dastlabki 10 ta qatorini chiqaring

# %%
df.head(10)
# Out:
#    stop_date stop_time  county_name driver_gender  driver_age_raw  driver_age  \
# 0   1/2/2005      1:55          NaN             M          1985.0        20.0
# 1  1/18/2005      8:15          NaN             M          1965.0        40.0
# 2  1/23/2005     23:15          NaN             M          1972.0        33.0
# 3  2/20/2005     17:15          NaN             M          1986.0        19.0
# 4  3/14/2005     10:00          NaN             F          1984.0        21.0
# 5  3/23/2005      9:45          NaN             M          1982.0        23.0
# 6   4/1/2005     17:30          NaN             M          1969.0        36.0
# 7   6/6/2005     13:20          NaN             F          1986.0        19.0
# 8  7/13/2005     10:15          NaN             M          1970.0        35.0
# 9  7/13/2005     15:45          NaN             M          1970.0        35.0
#
#   driver_race                   violation_raw  violation  search_conducted  \
# 0       White                        Speeding   Speeding             False
# 1       White                        Speeding   Speeding             False
# 2       White                        Speeding   Speeding             False
# 3       White                Call for Service      Other             False
# 4       White                        Speeding   Speeding             False
# 5       Black  Equipment/Inspection Violation  Equipment             False
# 6       White                        Speeding   Speeding             False
# 7       White                        Speeding   Speeding             False
# 8       Black                        Speeding   Speeding             False
# 9       White                        Speeding   Speeding             False
#
#   search_type   stop_outcome is_arrested stop_duration  drugs_related_stop
# 0         NaN       Citation       False      0-15 Min               False
# 1         NaN       Citation       False      0-15 Min               False
# 2         NaN       Citation       False      0-15 Min               False
# 3         NaN  Arrest Driver        True     16-30 Min               False
# 4         NaN       Citation       False      0-15 Min               False
# 5         NaN       Citation       False      0-15 Min               False
# 6         NaN       Citation       False      0-15 Min               False
# 7         NaN       Citation       False      0-15 Min               False
# 8         NaN       Citation       False      0-15 Min               False
# 9         NaN       Citation       False      0-15 Min               False

# %% [markdown]
# **4.** DataFramening eng so'nggi 7 ta qatorini chiqaring

# %%
df.tail(7)
# Out:
#         stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 91734  12/31/2015     20:20          NaN             M          1993.0
# 91735  12/31/2015     20:25          NaN             M          1992.0
# 91736  12/31/2015     20:27          NaN             M          1986.0
# 91737  12/31/2015     20:35          NaN             F          1982.0
# 91738  12/31/2015     20:45          NaN             M          1992.0
# 91739  12/31/2015     21:42          NaN             M          1993.0
# 91740  12/31/2015     22:46          NaN             M          1959.0
#
#        driver_age driver_race                   violation_raw  \
# 91734        22.0       White                        Speeding
# 91735        23.0    Hispanic                        Speeding
# 91736        29.0       White                        Speeding
# 91737        33.0       White  Equipment/Inspection Violation
# 91738        23.0       White         Other Traffic Violation
# 91739        22.0       White                        Speeding
# 91740        56.0    Hispanic                        Speeding
#
#               violation  search_conducted search_type stop_outcome  \
# 91734          Speeding             False         NaN     Citation
# 91735          Speeding             False         NaN     Citation
# 91736          Speeding             False         NaN      Warning
# 91737         Equipment             False         NaN      Warning
# 91738  Moving violation             False         NaN      Warning
# 91739          Speeding             False         NaN     Citation
# 91740          Speeding             False         NaN     Citation
#
#       is_arrested stop_duration  drugs_related_stop
# 91734       False      0-15 Min               False
# 91735       False      0-15 Min               False
# 91736       False      0-15 Min               False
# 91737       False      0-15 Min               False
# 91738       False      0-15 Min               False
# 91739       False      0-15 Min               False
# 91740       False      0-15 Min               False

# %% [markdown]
# **5.** Ma'lumotlar ichidan random tarzida 8 ta qatorni tanlab oling

# %%
df.sample(8)
# Out:
#         stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 37212    9/7/2009     21:00          NaN             F          1954.0
# 60731    6/9/2012      1:22          NaN             M          1984.0
# 25823   5/15/2008      7:33          NaN             M          1956.0
# 13979   1/22/2007     16:55          NaN             M          1984.0
# 30003  10/28/2008     22:14          NaN             F          1964.0
# 14982   2/25/2007     23:45          NaN             F          1987.0
# 8836     8/2/2006     17:50          NaN             M          1989.0
# 42185    5/7/2010      1:03          NaN             M          1986.0
#
#        driver_age driver_race                   violation_raw  \
# 37212        55.0       White                        Speeding
# 60731        28.0       White         Other Traffic Violation
# 25823        52.0    Hispanic                        Speeding
# 13979        23.0       White  Equipment/Inspection Violation
# 30003        44.0       Black  Equipment/Inspection Violation
# 14982        20.0       White                        Speeding
# 8836         17.0       White                        Speeding
# 42185        24.0       White                        Speeding
#
#               violation  search_conducted     search_type stop_outcome  \
# 37212          Speeding             False             NaN     Citation
# 60731  Moving violation             False             NaN     Citation
# 25823          Speeding             False             NaN     Citation
# 13979         Equipment             False             NaN     Citation
# 30003         Equipment             False             NaN     Citation
# 14982          Speeding             False             NaN     Citation
# 8836           Speeding             False             NaN     Citation
# 42185          Speeding              True  Probable Cause     Citation
#
#       is_arrested stop_duration  drugs_related_stop
# 37212       False      0-15 Min               False
# 60731       False      0-15 Min               False
# 25823       False      0-15 Min               False
# 13979       False      0-15 Min               False
# 30003       False     16-30 Min               False
# 14982       False      0-15 Min               False
# 8836        False     16-30 Min               False
# 42185       False     16-30 Min                True

# %% [markdown]
# **6.** DataFrame`ning 8332-qatoridagi ma'lumotlarni chiqaring

# %%
df.loc[8331]
# Out:
# stop_date                           7/15/2006
# stop_time                               16:05
# county_name                               NaN
# driver_gender                               M
# driver_age_raw                         1987.0
# driver_age                               19.0
# driver_race                             White
# violation_raw         Other Traffic Violation
# violation                    Moving violation
# search_conducted                        False
# search_type                               NaN
# stop_outcome                         Citation
# is_arrested                             False
# stop_duration                        0-15 Min
# drugs_related_stop                      False
# Name: 8331, dtype: object

# %% [markdown]
# **7.** DataFrame`ning 7654-indeksdagi qatorini chiqaring

# %%
df.loc[7654]
# Out:
# stop_date             6/20/2006
# stop_time                 19:45
# county_name                 NaN
# driver_gender                 M
# driver_age_raw           1986.0
# driver_age                 20.0
# driver_race               White
# violation_raw          Speeding
# violation              Speeding
# search_conducted          False
# search_type                 NaN
# stop_outcome           Citation
# is_arrested               False
# stop_duration          0-15 Min
# drugs_related_stop        False
# Name: 7654, dtype: object

# %% [markdown]
# **8.** Ma'lumotlarning 4332-qatoridan 4500-qatorigacha bo'lgan qismini qirqib oling

# %%
df.loc[4332:4500]
# Out:
#       stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 4332  2/27/2006     23:05          NaN             M          1972.0
# 4333  2/28/2006      0:29          NaN           NaN             NaN
# 4334  2/28/2006      0:30          NaN             M          1983.0
# 4335  2/28/2006      1:00          NaN             M          1967.0
# 4336  2/28/2006      2:15          NaN             M          1988.0
# ...         ...       ...          ...           ...             ...
# 4496   3/7/2006      9:05          NaN             M          1969.0
# 4497   3/7/2006      9:20          NaN             F          1973.0
# 4498   3/7/2006      9:30          NaN             M          1970.0
# 4499   3/7/2006      9:45          NaN             F          1976.0
# 4500   3/7/2006     10:00          NaN             M          1984.0
#
#       driver_age driver_race                   violation_raw  \
# 4332        34.0       White                        Speeding
# 4333         NaN         NaN                             NaN
# 4334        23.0       Black         Other Traffic Violation
# 4335        39.0       Black                        Speeding
# 4336        18.0       White  Equipment/Inspection Violation
# ...          ...         ...                             ...
# 4496        37.0       White                        Speeding
# 4497        33.0       White                        Speeding
# 4498        36.0       White                        Speeding
# 4499        30.0       White                        Speeding
# 4500        22.0       White                        Speeding
#
#              violation  search_conducted search_type stop_outcome is_arrested  \
# 4332          Speeding             False         NaN     Citation       False
# 4333               NaN             False         NaN          NaN         NaN
# 4334  Moving violation             False         NaN     Citation       False
# 4335          Speeding             False         NaN     Citation       False
# 4336         Equipment             False         NaN     Citation       False
# ...                ...               ...         ...          ...         ...
# 4496          Speeding             False         NaN     Citation       False
# 4497          Speeding             False         NaN     Citation       False
# 4498          Speeding             False         NaN     Citation       False
# 4499          Speeding             False         NaN     Citation       False
# 4500          Speeding             False         NaN     Citation       False
#
#      stop_duration  drugs_related_stop
# 4332      0-15 Min               False
# 4333           NaN               False
# 4334      0-15 Min               False
# 4335     16-30 Min               False
# 4336      0-15 Min               False
# ...            ...                 ...
# 4496      0-15 Min               False
# 4497      0-15 Min               False
# 4498      0-15 Min               False
# 4499      0-15 Min               False
# 4500      0-15 Min               False
#
# [169 rows x 15 columns]

# %% [markdown]
# **9.** DataFramening ustun va qatorlari almashtirilgan ko'rinishini chiqaring (transponirlang)

# %%
df.T
# Out:
#                        0          1          2                 3      \
# stop_date           1/2/2005  1/18/2005  1/23/2005         2/20/2005
# stop_time               1:55       8:15      23:15             17:15
# county_name              NaN        NaN        NaN               NaN
# driver_gender              M          M          M                 M
# driver_age_raw        1985.0     1965.0     1972.0            1986.0
# driver_age              20.0       40.0       33.0              19.0
# driver_race            White      White      White             White
# violation_raw       Speeding   Speeding   Speeding  Call for Service
# violation           Speeding   Speeding   Speeding             Other
# search_conducted       False      False      False             False
# search_type              NaN        NaN        NaN               NaN
# stop_outcome        Citation   Citation   Citation     Arrest Driver
# is_arrested            False      False      False              True
# stop_duration       0-15 Min   0-15 Min   0-15 Min         16-30 Min
# drugs_related_stop     False      False      False             False
#
#                         4                               5         6      \
# stop_date           3/14/2005                       3/23/2005  4/1/2005
# stop_time               10:00                            9:45     17:30
# county_name               NaN                             NaN       NaN
# driver_gender               F                               M         M
# driver_age_raw         1984.0                          1982.0    1969.0
# driver_age               21.0                            23.0      36.0
# driver_race             White                           Black     White
# violation_raw        Speeding  Equipment/Inspection Violation  Speeding
# violation            Speeding                       Equipment  Speeding
# search_conducted        False                           False     False
# search_type               NaN                             NaN       NaN
# stop_outcome         Citation                        Citation  Citation
# is_arrested             False                           False     False
# stop_duration        0-15 Min                        0-15 Min  0-15 Min
# drugs_related_stop      False                           False     False
#
#                        7          8          9      ...       91731  \
# stop_date           6/6/2005  7/13/2005  7/13/2005  ...  12/31/2015
# stop_time              13:20      10:15      15:45  ...       16:38
# county_name              NaN        NaN        NaN  ...         NaN
# driver_gender              F          M          M  ...           F
# driver_age_raw        1986.0     1970.0     1970.0  ...      1988.0
# driver_age              19.0       35.0       35.0  ...        27.0
# driver_race            White      Black      White  ...       White
# violation_raw       Speeding   Speeding   Speeding  ...    Speeding
# violation           Speeding   Speeding   Speeding  ...    Speeding
# search_conducted       False      False      False  ...       False
# search_type              NaN        NaN        NaN  ...         NaN
# stop_outcome        Citation   Citation   Citation  ...    Citation
# is_arrested            False      False      False  ...       False
# stop_duration       0-15 Min   0-15 Min   0-15 Min  ...    0-15 Min
# drugs_related_stop     False      False      False  ...       False
#
#                          91732                   91733       91734  \
# stop_date           12/31/2015              12/31/2015  12/31/2015
# stop_time                19:44                   19:55       20:20
# county_name                NaN                     NaN         NaN
# driver_gender                F                       F           M
# driver_age_raw          1969.0                  1974.0      1993.0
# driver_age                46.0                    41.0        22.0
# driver_race              White                   White       White
# violation_raw         Speeding  Registration Violation    Speeding
# violation             Speeding     Registration/plates    Speeding
# search_conducted         False                   False       False
# search_type                NaN                     NaN         NaN
# stop_outcome           Warning                Citation    Citation
# is_arrested              False                   False       False
# stop_duration         0-15 Min                0-15 Min    0-15 Min
# drugs_related_stop       False                   False       False
#
#                          91735       91736                           91737  \
# stop_date           12/31/2015  12/31/2015                      12/31/2015
# stop_time                20:25       20:27                           20:35
# county_name                NaN         NaN                             NaN
# driver_gender                M           M                               F
# driver_age_raw          1992.0      1986.0                          1982.0
# driver_age                23.0        29.0                            33.0
# driver_race           Hispanic       White                           White
# violation_raw         Speeding    Speeding  Equipment/Inspection Violation
# violation             Speeding    Speeding                       Equipment
# search_conducted         False       False                           False
# search_type                NaN         NaN                             NaN
# stop_outcome          Citation     Warning                         Warning
# is_arrested              False       False                           False
# stop_duration         0-15 Min    0-15 Min                        0-15 Min
# drugs_related_stop       False       False                           False
#
#                                       91738       91739       91740
# stop_date                        12/31/2015  12/31/2015  12/31/2015
# stop_time                             20:45       21:42       22:46
# county_name                             NaN         NaN         NaN
# driver_gender                             M           M           M
# driver_age_raw                       1992.0      1993.0      1959.0
# driver_age                             23.0        22.0        56.0
# driver_race                           White       White    Hispanic
# violation_raw       Other Traffic Violation    Speeding    Speeding
# violation                  Moving violation    Speeding    Speeding
# search_conducted                      False       False       False
# search_type                             NaN         NaN         NaN
# stop_outcome                        Warning    Citation    Citation
# is_arrested                           False       False       False
# stop_duration                      0-15 Min    0-15 Min    0-15 Min
# drugs_related_stop                    False       False       False
#
# [15 rows x 91741 columns]

# %% [markdown]
# **10.** DataFrame`dan random tarzida 10 ta qatorini qirqib oling va uni yangi df2 obyektiga saqlang

# %%
df2 = df.sample(10)
df2
# Out:
#         stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 49282    5/3/2011     10:32          NaN             M          1964.0
# 87216    7/7/2015     17:59          NaN             M          1973.0
# 41745   4/16/2010     14:06          NaN             M          1975.0
# 57165   2/26/2012     21:45          NaN             M          1966.0
# 19173    8/5/2007     20:00          NaN             M          1949.0
# 20596   10/3/2007     10:50          NaN             M          1982.0
# 62128   7/22/2012      2:43          NaN             M          1968.0
# 82609   12/5/2014     11:58          NaN             M          1986.0
# 22468  12/20/2007      8:55          NaN             M          1978.0
# 56750   2/15/2012     15:41          NaN             M          1988.0
#
#        driver_age driver_race                   violation_raw  \
# 49282        47.0       White  Special Detail/Directed Patrol
# 87216        42.0       White         Other Traffic Violation
# 41745        35.0       White         Other Traffic Violation
# 57165        46.0       White         Other Traffic Violation
# 19173        58.0       White                        Speeding
# 20596        25.0       White                        Speeding
# 62128        44.0       White                        Speeding
# 82609        28.0    Hispanic                        Speeding
# 22468        29.0       White         Other Traffic Violation
# 56750        24.0       Black        Motorist Assist/Courtesy
#
#               violation  search_conducted     search_type stop_outcome  \
# 49282             Other             False             NaN     Citation
# 87216  Moving violation             False             NaN      Warning
# 41745  Moving violation             False             NaN     Citation
# 57165  Moving violation             False             NaN     Citation
# 19173          Speeding             False             NaN     Citation
# 20596          Speeding             False             NaN     Citation
# 62128          Speeding             False             NaN      Warning
# 82609          Speeding             False             NaN     Citation
# 22468  Moving violation             False             NaN     Citation
# 56750             Other              True  Probable Cause      Warning
#
#       is_arrested stop_duration  drugs_related_stop
# 49282       False      0-15 Min               False
# 87216       False      0-15 Min               False
# 41745       False     16-30 Min               False
# 57165       False     16-30 Min               False
# 19173       False      0-15 Min               False
# 20596       False      0-15 Min               False
# 62128       False      0-15 Min               False
# 82609       False      0-15 Min               False
# 22468       False       30+ Min               False
# 56750       False     16-30 Min                True

# %% [markdown]
# **11.** Qirqib olingan df2 obyektining indekslarini o'sib borish tartibida saralang

# %%
df2.sort_index()
# Out:
#         stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 19173    8/5/2007     20:00          NaN             M          1949.0
# 20596   10/3/2007     10:50          NaN             M          1982.0
# 22468  12/20/2007      8:55          NaN             M          1978.0
# 41745   4/16/2010     14:06          NaN             M          1975.0
# 49282    5/3/2011     10:32          NaN             M          1964.0
# 56750   2/15/2012     15:41          NaN             M          1988.0
# 57165   2/26/2012     21:45          NaN             M          1966.0
# 62128   7/22/2012      2:43          NaN             M          1968.0
# 82609   12/5/2014     11:58          NaN             M          1986.0
# 87216    7/7/2015     17:59          NaN             M          1973.0
#
#        driver_age driver_race                   violation_raw  \
# 19173        58.0       White                        Speeding
# 20596        25.0       White                        Speeding
# 22468        29.0       White         Other Traffic Violation
# 41745        35.0       White         Other Traffic Violation
# 49282        47.0       White  Special Detail/Directed Patrol
# 56750        24.0       Black        Motorist Assist/Courtesy
# 57165        46.0       White         Other Traffic Violation
# 62128        44.0       White                        Speeding
# 82609        28.0    Hispanic                        Speeding
# 87216        42.0       White         Other Traffic Violation
#
#               violation  search_conducted     search_type stop_outcome  \
# 19173          Speeding             False             NaN     Citation
# 20596          Speeding             False             NaN     Citation
# 22468  Moving violation             False             NaN     Citation
# 41745  Moving violation             False             NaN     Citation
# 49282             Other             False             NaN     Citation
# 56750             Other              True  Probable Cause      Warning
# 57165  Moving violation             False             NaN     Citation
# 62128          Speeding             False             NaN      Warning
# 82609          Speeding             False             NaN     Citation
# 87216  Moving violation             False             NaN      Warning
#
#       is_arrested stop_duration  drugs_related_stop
# 19173       False      0-15 Min               False
# 20596       False      0-15 Min               False
# 22468       False       30+ Min               False
# 41745       False     16-30 Min               False
# 49282       False      0-15 Min               False
# 56750       False     16-30 Min                True
# 57165       False     16-30 Min               False
# 62128       False      0-15 Min               False
# 82609       False      0-15 Min               False
# 87216       False      0-15 Min               False

# %% [markdown]
# **12.** df2 ma'lumotlarini `stop_date` va `stop_time` ustunlari bo'yicha saralang

# %%
df2.sort_values(['stop_date', 'stop_time'])
# Out:
#         stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 20596   10/3/2007     10:50          NaN             M          1982.0
# 22468  12/20/2007      8:55          NaN             M          1978.0
# 82609   12/5/2014     11:58          NaN             M          1986.0
# 56750   2/15/2012     15:41          NaN             M          1988.0
# 57165   2/26/2012     21:45          NaN             M          1966.0
# 41745   4/16/2010     14:06          NaN             M          1975.0
# 49282    5/3/2011     10:32          NaN             M          1964.0
# 62128   7/22/2012      2:43          NaN             M          1968.0
# 87216    7/7/2015     17:59          NaN             M          1973.0
# 19173    8/5/2007     20:00          NaN             M          1949.0
#
#        driver_age driver_race                   violation_raw  \
# 20596        25.0       White                        Speeding
# 22468        29.0       White         Other Traffic Violation
# 82609        28.0    Hispanic                        Speeding
# 56750        24.0       Black        Motorist Assist/Courtesy
# 57165        46.0       White         Other Traffic Violation
# 41745        35.0       White         Other Traffic Violation
# 49282        47.0       White  Special Detail/Directed Patrol
# 62128        44.0       White                        Speeding
# 87216        42.0       White         Other Traffic Violation
# 19173        58.0       White                        Speeding
#
#               violation  search_conducted     search_type stop_outcome  \
# 20596          Speeding             False             NaN     Citation
# 22468  Moving violation             False             NaN     Citation
# 82609          Speeding             False             NaN     Citation
# 56750             Other              True  Probable Cause      Warning
# 57165  Moving violation             False             NaN     Citation
# 41745  Moving violation             False             NaN     Citation
# 49282             Other             False             NaN     Citation
# 62128          Speeding             False             NaN      Warning
# 87216  Moving violation             False             NaN      Warning
# 19173          Speeding             False             NaN     Citation
#
#       is_arrested stop_duration  drugs_related_stop
# 20596       False      0-15 Min               False
# 22468       False       30+ Min               False
# 82609       False      0-15 Min               False
# 56750       False     16-30 Min                True
# 57165       False     16-30 Min               False
# 41745       False     16-30 Min               False
# 49282       False      0-15 Min               False
# 62128       False      0-15 Min               False
# 87216       False      0-15 Min               False
# 19173       False      0-15 Min               False

# %% [markdown]
# **13.** df2 DataFrame`ni a dan boshlab harflar yordamida qayta indekslang

# %%
import string
index = list(string.ascii_lowercase[:10])

# %%
df2.index = index
df2
# Out:
#     stop_date stop_time  county_name driver_gender  driver_age_raw  \
# a    5/3/2011     10:32          NaN             M          1964.0
# b    7/7/2015     17:59          NaN             M          1973.0
# c   4/16/2010     14:06          NaN             M          1975.0
# d   2/26/2012     21:45          NaN             M          1966.0
# e    8/5/2007     20:00          NaN             M          1949.0
# f   10/3/2007     10:50          NaN             M          1982.0
# g   7/22/2012      2:43          NaN             M          1968.0
# h   12/5/2014     11:58          NaN             M          1986.0
# i  12/20/2007      8:55          NaN             M          1978.0
# j   2/15/2012     15:41          NaN             M          1988.0
#
#    driver_age driver_race                   violation_raw         violation  \
# a        47.0       White  Special Detail/Directed Patrol             Other
# b        42.0       White         Other Traffic Violation  Moving violation
# c        35.0       White         Other Traffic Violation  Moving violation
# d        46.0       White         Other Traffic Violation  Moving violation
# e        58.0       White                        Speeding          Speeding
# f        25.0       White                        Speeding          Speeding
# g        44.0       White                        Speeding          Speeding
# h        28.0    Hispanic                        Speeding          Speeding
# i        29.0       White         Other Traffic Violation  Moving violation
# j        24.0       Black        Motorist Assist/Courtesy             Other
#
#    search_conducted     search_type stop_outcome is_arrested stop_duration  \
# a             False             NaN     Citation       False      0-15 Min
# b             False             NaN      Warning       False      0-15 Min
# c             False             NaN     Citation       False     16-30 Min
# d             False             NaN     Citation       False     16-30 Min
# e             False             NaN     Citation       False      0-15 Min
# f             False             NaN     Citation       False      0-15 Min
# g             False             NaN      Warning       False      0-15 Min
# h             False             NaN     Citation       False      0-15 Min
# i             False             NaN     Citation       False       30+ Min
# j              True  Probable Cause      Warning       False     16-30 Min
#
#    drugs_related_stop
# a               False
# b               False
# c               False
# d               False
# e               False
# f               False
# g               False
# h               False
# i               False
# j                True

# %% [markdown]
# **14.** df2 ga yangi `fullname_of_driver` ustunini qo'shing va ustundagi barcha qiymatlarni nan ga tenglang

# %%
df2["fullname_of_driver"] = np.nan
df2.columns
# Out:
# Index(['stop_date', 'stop_time', 'county_name', 'driver_gender',
#        'driver_age_raw', 'driver_age', 'driver_race', 'violation_raw',
#        'violation', 'search_conducted', 'search_type', 'stop_outcome',
#        'is_arrested', 'stop_duration', 'drugs_related_stop',
#        'fullname_of_driver'],
#       dtype='object')

# %% [markdown]
# **15.** df2 DataFramedan `county_name` ustunini olib tashlang

# %%
df2.drop('county_name', axis=1, inplace=True)

# %% [markdown]
# **16.** df2 jadvalining 3-qator 4-ustun kesishmasida joylashgan qiymatni chop eting

# %%
value = df2.iloc[2,3]
value
# Out:
# 1975.0

# %% [markdown]
# **17.** df jadvalidagi nan qiymatga ega barcha qatorlarni tashlab yuboring

# %%
df.dropna(axis=0)
df.shape
# Out:
# (91741, 15)

# %% [markdown]
# **18.** df2 jadvalidagi barcha nan qiymatlarni 0 bilan to'ldiring

# %%
df2.fillna(0)
# Out:
#     stop_date stop_time driver_gender  driver_age_raw  driver_age driver_race  \
# a    5/3/2011     10:32             M          1964.0        47.0       White
# b    7/7/2015     17:59             M          1973.0        42.0       White
# c   4/16/2010     14:06             M          1975.0        35.0       White
# d   2/26/2012     21:45             M          1966.0        46.0       White
# e    8/5/2007     20:00             M          1949.0        58.0       White
# f   10/3/2007     10:50             M          1982.0        25.0       White
# g   7/22/2012      2:43             M          1968.0        44.0       White
# h   12/5/2014     11:58             M          1986.0        28.0    Hispanic
# i  12/20/2007      8:55             M          1978.0        29.0       White
# j   2/15/2012     15:41             M          1988.0        24.0       Black
#
#                     violation_raw         violation  search_conducted  \
# a  Special Detail/Directed Patrol             Other             False
# b         Other Traffic Violation  Moving violation             False
# c         Other Traffic Violation  Moving violation             False
# d         Other Traffic Violation  Moving violation             False
# e                        Speeding          Speeding             False
# f                        Speeding          Speeding             False
# g                        Speeding          Speeding             False
# h                        Speeding          Speeding             False
# i         Other Traffic Violation  Moving violation             False
# j        Motorist Assist/Courtesy             Other              True
#
#       search_type stop_outcome  is_arrested stop_duration  drugs_related_stop  \
# a               0     Citation        False      0-15 Min               False
# b               0      Warning        False      0-15 Min               False
# c               0     Citation        False     16-30 Min               False
# d               0     Citation        False     16-30 Min               False
# e               0     Citation        False      0-15 Min               False
# f               0     Citation        False      0-15 Min               False
# g               0      Warning        False      0-15 Min               False
# h               0     Citation        False      0-15 Min               False
# i               0     Citation        False       30+ Min               False
# j  Probable Cause      Warning        False     16-30 Min                True
#
#    fullname_of_driver
# a                 0.0
# b                 0.0
# c                 0.0
# d                 0.0
# e                 0.0
# f                 0.0
# g                 0.0
# h                 0.0
# i                 0.0
# j                 0.0

# %% [markdown]
# **19.** df DataFramening ustun, qator, xotira va ma'lumotlar turlari bo'yicha barcha ma'lumotlarini chop eting

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91741 entries, 0 to 91740
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   stop_date           91741 non-null  object
#  1   stop_time           91741 non-null  object
#  2   county_name         0 non-null      float64
#  3   driver_gender       86406 non-null  object
#  4   driver_age_raw      86414 non-null  float64
#  5   driver_age          86120 non-null  float64
#  6   driver_race         86408 non-null  object
#  7   violation_raw       86408 non-null  object
#  8   violation           86408 non-null  object
#  9   search_conducted    91741 non-null  bool
#  10  search_type         3196 non-null   object
#  11  stop_outcome        86408 non-null  object
#  12  is_arrested         86408 non-null  object
#  13  stop_duration       86408 non-null  object
#  14  drugs_related_stop  91741 non-null  bool
# dtypes: bool(2), float64(3), object(10)
# memory usage: 9.3+ MB

# %% [markdown]
# **20.** df jadvalining `driver_age_raw` ustunidagi qiymatlarning o'rta arifmetigini hisoblang

# %%
df['driver_age_raw'].mean()
# Out:
# 1970.4912282731964

# %% [markdown]
# **21.** df jadvalining `drive_age` ustunidagi qiymatlar uchun standart og'ishni hisoblang

# %%
df['driver_age'].std()
# Out:
# 12.738563812761932

# %% [markdown]
# **22.** df jadvalida necha nafar ayollar va necha nafar erkaklar ma'lumotlari mavjud ekanligini aniqlang

# %%
df['driver_gender'].value_counts()
# Out:
# M    62895
# F    23511
# Name: driver_gender, dtype: int64

# %% [markdown]
# **23.** df ma'lumotlarining `violation_raw` ustunida necha xil ma'lumotlar bor ekanligini aniqlang

# %%
df['violation_raw'].value_counts()
# Out:
# Speeding                            48463
# Other Traffic Violation             16224
# Equipment/Inspection Violation      11020
# Registration Violation               3432
# Seatbelt Violation                   2952
# Special Detail/Directed Patrol       2455
# Call for Service                     1298
# Violation of City/Town Ordinance      211
# Motorist Assist/Courtesy              203
# APB                                    79
# Suspicious Person                      56
# Warrant                                15
# Name: violation_raw, dtype: int64

# %%
from IPython.display import Image

# Display the GIF file
display(Image(filename='E:\Data science\pro_data_scientist\done.jpg'))
